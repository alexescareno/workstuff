# %%
import sqlite3
import pandas as pd

# %%
###CONNECTING to data using python with the database in your python repository, copy and pasting the path will also work
con = sqlite3.connect("sakila.db")

# %%
### an example of selecting data from a data base using pandas
sql_query = ''' SELECT * FROM customer '''

# %%
sql_query
# Out:
# ' SELECT * FROM customer '

# %%
df = pd.read_sql(sql_query, con)

# %%
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id active  \
# 0            MARY.SMITH@sakilacustomer.org           5      1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6      1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7      1
# 3         BARBARA.JONES@sakilacustomer.org           8      1
# ...

# %%
####using a function I learned to turn comments into sql queries
def sql_to_df(sql_query):
    df = pd.read_sql(sql_query, con)
    return df

# %%
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id active  \
# 0            MARY.SMITH@sakilacustomer.org           5      1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6      1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7      1
# 3         BARBARA.JONES@sakilacustomer.org           8      1
# ...

# %%
###SELECTING data and turning it into a data frame using python
query = ''' SELECT first_name,last_name 
            FROM customer; '''
sql_to_df(query).head()
# Out:
#   first_name last_name
# 0       MARY     SMITH
# 1   PATRICIA   JOHNSON
# 2      LINDA  WILLIAMS
# 3    BARBARA     JONES
# 4  ELIZABETH     BROWN

# %%
###SELECTING continued
query = ''' SELECT *
            FROM customer; '''
sql_to_df(query).head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id active  \
# 0        MARY.SMITH@sakilacustomer.org           5      1
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6      1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7      1
# 3     BARBARA.JONES@sakilacustomer.org           8      1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 1  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 2  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 3  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 4  2006-02-14 22:04:36.000  2011-09-14 18:10:28

# %%
##using DISTINCT, to not count twice things such as duplicates.
query = ''' SELECT DISTINCT(country_id)
            FROM city'''
sql_to_df(query)
# Out:
#      country_id
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ..          ...
# 104         105
# 105         106
# 106         107
# 107         108
# 108         109
#
# [109 rows x 1 columns]

# %%
##USING FROM, WHERE, AND
query = '''SELECT *
            FROM film
            WHERE release_year = 2006
            AND rating = 'R' '''
sql_to_df(query).head()
# Out:
#    film_id                 title  \
# 0        8       AIRPORT POLLOCK
# 1       17            ALONE TRIP
# 2       20   AMELIE HELLFIGHTERS
# 3       21       AMERICAN CIRCUS
# 4       23  ANACONDA CONFESSIONS
#
#                                          description release_year  \
# 0  A Epic Tale of a Moose And a Girl who must Con...         2006
# 1  A Fast-Paced Character Study of a Composer And...         2006
# 2  A Boring Drama of a Woman And a Squirrel who m...         2006
# 3  A Insightful Drama of a Girl And a Astronaut w...         2006
# 4  A Lacklusture Display of a Dentist And a Denti...         2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                6         4.99      54
# 1            1                 None                3         0.99      82
# 2            1                 None                4         4.99      79
# ...

# %%
#### using COUNT
query = '''SELECT COUNT(customer_id)
            FROM CUSTOMER'''
sql_to_df(query).head()
# Out:
#    COUNT(customer_id)
# 0                 599

# %%
###USING LIKE WITH ' % ' or ' _ ' to search for strings in data with the M character in the first_name column

query = '''SELECT * 
           FROM customer
           WHERE first_name LIKE 'M%' '''

# %%
sql_to_df(query).head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            7         1      MARIA    MILLER
# 2            9         2   MARGARET     MOORE
# 3           21         1   MICHELLE     CLARK
# 4           30         1    MELISSA      KING
#
#                                email  address_id active  \
# 0      MARY.SMITH@sakilacustomer.org           5      1
# 1    MARIA.MILLER@sakilacustomer.org          11      1
# 2  MARGARET.MOORE@sakilacustomer.org          13      1
# 3  MICHELLE.CLARK@sakilacustomer.org          25      1
# 4    MELISSA.KING@sakilacustomer.org          34      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 1  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 2  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 3  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 4  2006-02-14 22:04:36.000  2011-09-14 18:10:29

# %%
##the same here, again just searching names using LIKE but with ' _ ' 
query = '''SELECT * FROM
            customer WHERE
            last_name LIKE '_ing' '''

sql_to_df(query).head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0           30         1    MELISSA      KING
#
#                              email  address_id active  \
# 0  MELISSA.KING@sakilacustomer.org          34      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:29

# %%
## Using GLOB to grab a list of names in the first name that start with either A or B
query = ''' SELECT * FROM
            customer WHERE
            first_name GLOB '[AB]*' ; '''

sql_to_df(query).head()
# Out:
#    customer_id  store_id first_name  last_name  \
# 0            4         2    BARBARA      JONES
# 1           14         2      BETTY      WHITE
# 2           29         2     ANGELA  HERNANDEZ
# 3           31         2     BRENDA     WRIGHT
# 4           32         1        AMY      LOPEZ
#
#                                  email  address_id active  \
# 0     BARBARA.JONES@sakilacustomer.org           8      1
# 1       BETTY.WHITE@sakilacustomer.org          18      1
# 2  ANGELA.HERNANDEZ@sakilacustomer.org          33      1
# 3     BRENDA.WRIGHT@sakilacustomer.org          35      1
# 4         AMY.LOPEZ@sakilacustomer.org          36      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 1  2006-02-14 22:04:36.000  2011-09-14 18:10:28
# 2  2006-02-14 22:04:36.000  2011-09-14 18:10:29
# 3  2006-02-14 22:04:36.000  2011-09-14 18:10:29
# 4  2006-02-14 22:04:36.000  2011-09-14 18:10:29

# %%
#Using ORDER BY to sort a list of last names in descending order
query = '''SELECT *
            FROM customer
            ORDER BY last_name  DESC; '''

sql_to_df(query).head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0           28         1    CYNTHIA     YOUNG
# 1          413         2     MARVIN       YEE
# 2          402         1       LUIS     YANEZ
# 3          318         1      BRIAN     WYMAN
# 4           31         2     BRENDA    WRIGHT
#
#                               email  address_id active  \
# 0  CYNTHIA.YOUNG@sakilacustomer.org          32      1
# 1     MARVIN.YEE@sakilacustomer.org         418      1
# 2     LUIS.YANEZ@sakilacustomer.org         407      1
# 3    BRIAN.WYMAN@sakilacustomer.org         323      1
# 4  BRENDA.WRIGHT@sakilacustomer.org          35      1
#
#                create_date          last_update
# 0  2006-02-14 22:04:36.000  2011-09-14 18:10:29
# 1  2006-02-14 22:04:37.000  2011-09-14 18:10:40
# 2  2006-02-14 22:04:37.000  2011-09-14 18:10:39
# 3  2006-02-14 22:04:37.000  2011-09-14 18:10:37
# 4  2006-02-14 22:04:36.000  2011-09-14 18:10:29

# %%
#Using GROUP BY to do a count using the store ids and counting the customer ids

query = '''SELECT store_id, COUNT(customer_id)
            FROM customer
            GROUP BY store_id;'''

sql_to_df(query).head()
# Out:
#    store_id  COUNT(customer_id)
# 0         1                 326
# 1         2                 273
